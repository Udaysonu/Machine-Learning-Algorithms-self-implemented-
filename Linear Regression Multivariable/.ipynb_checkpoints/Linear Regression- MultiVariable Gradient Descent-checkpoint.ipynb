# %% [markdown]
# # Linear regression using multi variable Gradient Descent
# ###Code written by Uday kiran Bakka

# %%
#import required libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
#import dataset and divide it into x_train and y_train
data=np.loadtxt("train_boston_x_y.csv",delimiter=",")
x_train=data[:,:-1]
y_train=data[:,-1]

# %%
#Create a class LinearRegression to do all the operations of linear regression
class LinearRegression:
    #when ever an object is created you can pass iteration and learning rage
    def __init__(self,it=100,lr=0.1):
        self.learning_rate=lr
        self.iterations=it
        self.m=[]
        
        
    #gradientdescent which optimizes our solution
    def GradientDescent(self,x,y,m_slope):        
        new_m_slope=np.zeros(len(x[0]))
        for i in range(len(x)):
            for j in range(len(x[0])):
                new_m_slope[j] += (-2/len(x))*(y[i]-sum(m_slope*x[i]))*(x[i][j])
        return m_slope-self.learning_rate*new_m_slope
    
    
    #cost function which calculates our cost
    def cost(self,x_train,y_train,m_slope):
        value=0
        for i in range(len(x_train)):
            value+=(y_train[i]-sum(x_train[i]*m_slope))**2
        #YOU CAN UNCOMMENT THE BELOW CODE TO SEE HOW GRADIENT DESCENT WORKS GRAPHICALLY
#         for i in range(len(x_train[0])-1):
#             plt.plot(x_train[:,i],(m_slope[i]*x_train[:,i]+m_slope[-1]),color="red")
#             plt.scatter(x_train[:,i],y_train)
#             plt.show()
        return value/len(x_train)
        
        
        
    #fit function receives our x_train and y_train and calculates m_slope
    def fit(self,x_train,y_train):
        x_train=np.array(x_train)
        zeros=np.ones(shape=(len(x_train),1),dtype=float)
        x_train=np.append(x_train,zeros,axis=1)
        m_slope=np.array([0 for i in range(len(x_train[0]))],dtype=float)
        
        for i in range(self.iterations):
            m_slope=self.GradientDescent(x_train,y_train,m_slope)
            print("Iteration Number-",i+1,"Cost=",self.cost(x_train,y_train,m_slope))
        self.m=m_slope
        
        
        
    #function to return intercept
    def intercept(self):
        return self.m[-1]
    
    
    
    #funciton to return coefficients
    def coef_(self):
        return self.m[:-1]
    
    
    
    #function to predict the answer by taking x_test
    def predict(self,x):
        print(x[0])
        y_predict=[]
        x=np.array(x)
        ones=np.ones(shape=(len(x),1))
        x=np.append(x,ones,axis=1)
        for i in range(len(x)):
            y_predict.append(sum(self.m*x[i]))
        print(y_predict[0])
        return y_predict
    
    
    
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# Iteration Number- 1 Cost= 374.24035597919686
# Iteration Number- 2 Cost= 245.379096560799
# Iteration Number- 3 Cost= 165.10614192173674
# Iteration Number- 4 Cost= 114.4950862119168
# Iteration Number- 5 Cost= 82.43432664281792
# Iteration Number- 6 Cost= 62.04170468831088
# Iteration Number- 7 Cost= 49.01547466604823
# Iteration Number- 8 Cost= 40.65519326019774
# Iteration Number- 9 Cost= 35.25972835067589
# Iteration Number- 10 Cost= 31.754121492629714
# Iteration Number- 11 Cost= 29.457161634001746
# Iteration Number- 12 Cost= 27.936007022144544
# Iteration Number- 13 Cost= 26.914922412896345
# Iteration Number- 14 Cost= 26.21780295198017
# Iteration Number- 15 Cost= 25.73187282296313
# Iteration Number- 16 Cost= 25.38469911771804
# Iteration Number- 17 Cost= 25.129603525591058
# Iteration Number- 18 Cost= 24.93638441051881
# Iteration Number- 19 Cost= 24.785404792037347
# Iteration Number- 20 Cost= 24.663818221907498
# Iteration Number- 21 Cost= 24.56315514362142
# Iteration Number- 22 Cost= 24.477776518190076
# Iteration Number- 23 Cost= 24.40388120070021
# Iteration Number- 24 Cost= 24.338867434896205
# Iteration Number- 25 Cost= 24.280921148348437
# Iteration Number- 26 Cost= 24.228749732407834
# Iteration Number- 27 Cost= 24.1814093005852
# Iteration Number- 28 Cost= 24.138192120101184
# Iteration Number- 29 Cost= 24.098552859489267
# Iteration Number- 30 Cost= 24.06205993819116
# Iteration Number- 31 Cost= 24.028363158977236
# Iteration Number- 32 Cost= 23.997171942483206
# Iteration Number- 33 Cost= 23.96824049778333
# Iteration Number- 34 Cost= 23.941357557710425
# Iteration Number- 35 Cost= 23.91633914089354
# Iteration Number- 36 Cost= 23.8930233395274
# Iteration Number- 37 Cost= 23.87126647861827
# Iteration Number- 38 Cost= 23.850940216777783
# Iteration Number- 39 Cost= 23.831929304140584
# Iteration Number- 40 Cost= 23.814129807654254
# Iteration Number- 41 Cost= 23.79744767583678
# Iteration Number- 42 Cost= 23.781797555694695
# Iteration Number- 43 Cost= 23.76710180131216
# Iteration Number- 44 Cost= 23.753289631473635
# Iteration Number- 45 Cost= 23.74029640567708
# Iteration Number- 46 Cost= 23.728062996050742
# Iteration Number- 47 Cost= 23.716535238305692
# Iteration Number- 48 Cost= 23.705663448792908
# Iteration Number- 49 Cost= 23.695401997540305
# Iteration Number- 50 Cost= 23.68570892918505
# Iteration Number- 51 Cost= 23.676545625233395
# Iteration Number- 52 Cost= 23.66787650222818
# Iteration Number- 53 Cost= 23.659668741294784
# Iteration Number- 54 Cost= 23.651892045237428
# Iteration Number- 55 Cost= 23.644518419921994
# Iteration Number- 56 Cost= 23.63752197714232
# Iteration Number- 57 Cost= 23.630878756545357
# Iteration Number- 58 Cost= 23.62456656451033
# Iteration Number- 59 Cost= 23.61856482814463
# Iteration Number- 60 Cost= 23.612854462787244
# Iteration Number- 61 Cost= 23.607417751606434
# Iteration Number- 62 Cost= 23.602238236046134
# Iteration Number- 63 Cost= 23.597300616021244
# Iteration Number- 64 Cost= 23.592590658888138
# Iteration Number- 65 Cost= 23.58809511632605
# Iteration Number- 66 Cost= 23.58380164836196
# Iteration Number- 67 Cost= 23.579698753854316
# Iteration Number- 68 Cost= 23.575775706825425
# Iteration Number- 69 Cost= 23.572022498097425
# Iteration Number- 70 Cost= 23.56842978174196
# Iteration Number- 71 Cost= 23.564988825906948
# Iteration Number- 72 Cost= 23.561691467625874
# Iteration Number- 73 Cost= 23.558530071255543
# Iteration Number- 74 Cost= 23.55549749022371
# Iteration Number- 75 Cost= 23.552587031798264
# Iteration Number- 76 Cost= 23.549792424617923
# Iteration Number- 77 Cost= 23.54710778874907
# Iteration Number- 78 Cost= 23.54452760805564
# Iteration Number- 79 Cost= 23.542046704688303
# Iteration Number- 80 Cost= 23.539660215517653
# Iteration Number- 81 Cost= 23.537363570351086
# Iteration Number- 82 Cost= 23.53515247178878
# Iteration Number- 83 Cost= 23.53302287658537
# Iteration Number- 84 Cost= 23.530970978397207
# Iteration Number- 85 Cost= 23.52899319180437
# Iteration Number- 86 Cost= 23.52708613750682
# Iteration Number- 87 Cost= 23.52524662860239
# Iteration Number- 88 Cost= 23.523471657862018
# Iteration Number- 89 Cost= 23.521758385925104
# Iteration Number- 90 Cost= 23.52010413034386
# Iteration Number- 91 Cost= 23.518506355411592
# Iteration Number- 92 Cost= 23.516962662715116
# Iteration Number- 93 Cost= 23.515470782356633
# Iteration Number- 94 Cost= 23.514028564794046
# Iteration Number- 95 Cost= 23.51263397325361
# Iteration Number- 96 Cost= 23.511285076672532
# Iteration Number- 97 Cost= 23.509980043131133
# Iteration Number- 98 Cost= 23.508717133739296
# Iteration Number- 99 Cost= 23.50749469694332
# Iteration Number- 100 Cost= 23.506311163222136

# %%
y_pred=lr.predict(x_train)
# Out:
# [-0.40784991 -0.48772236 -1.2660231  -0.27259857 -0.57613394  1.23997392
#   0.84012202 -0.52026428 -0.75292215 -1.27835435 -0.30309415  0.41057102
#  -1.09799011]
# 34.05072571313353

# %%
y_pred
# Out:
# [34.05072571313353,
#  24.652800992537635,
#  13.508267988315076,
#  18.95737367630271,
#  22.3847416317834,
#  30.91345198161334,
#  22.31689281506337,
#  21.035954326263962,
#  20.33979762037882,
#  36.32795512849497,
#  25.24923417085798,
#  23.481976688293138,
#  42.87035452252127,
#  26.385864932901583,
#  22.56595420704425,
#  19.056616933867367,
#  23.026261760943477,
#  20.06758644466653,
#  19.612401845525202,
#  33.206186971388085,
#  21.089748057243135,
#  31.025224386996562,
#  35.02785934804102,
#  26.02087957343017,
#  21.514677684020317,
#  19.684652764314805,
#  13.19238412208909,
#  33.01382253331972,
#  28.405718227988505,
#  29.482504908147746,
#  27.171766726015683,
#  19.69093939707498,
#  32.407501171631864,
#  16.88171799255074,
#  34.70603925711694,
#  7.018406543151007,
#  9.438031902895654,
#  14.552893213449133,
#  34.42520920884349,
#  23.705644440899917,
#  17.52062597439097,
#  29.921684510154567,
#  25.585364982336603,
#  12.509061898908598,
#  14.287291685113578,
#  19.609915311912673,
#  27.141402665638577,
#  24.906308823484235,
#  8.005768876164034,
#  13.31599842949949,
#  14.483877859678,
#  19.874495585675966,
#  18.899788715724874,
#  38.259616654573044,
#  25.43845765618736,
#  12.471865607998792,
#  25.14067477443252,
#  17.756977069123323,
#  28.536470339387414,
#  30.704057769472396,
#  14.731878005542422,
#  18.564885014296088,
#  35.34860387604866,
#  13.951442267310071,
#  17.178401176466053,
#  25.647382050914196,
#  19.468601439314803,
#  17.142558680369458,
#  12.94107853532456,
#  44.11998209596913,
#  19.04700589621751,
#  30.131991571231698,
#  11.237138621903572,
#  26.128732288942857,
#  20.51892874709683,
#  19.729944835132144,
#  17.261871072669855,
#  33.05026327888004,
#  7.880176954343639,
#  21.629121753236227,
#  15.402118166054054,
#  27.20466249317264,
#  26.607911843166242,
#  25.978406724820157,
#  9.060551559168204,
#  20.023827698374376,
#  12.56238653039423,
#  17.51691247690872,
#  19.475767464116593,
#  13.458761085102324,
#  18.133842745205076,
#  22.51157197468658,
#  20.050747106768362,
